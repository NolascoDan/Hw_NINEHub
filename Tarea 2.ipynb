# %% [markdown]
# # Tarea 2
#
# - Cargue los datos de meteorite_landins.csv de la sesión 3
# - Cree un nuevo dataframe llamado meteoritos_h4. En este dataframe, utilizando la función str. seleccione todos los meteoritos solamente de categoría H4
# - Cree otro dataframe llamado meteoritos_h5. En este dataframe, utilizando la función str. seleccione todos los meteoritos de solamente categoría H5
# - Limpie los datos de ambos dataframes, eliminando las entradas donde las masas sean cero, null, NaN, etc.
# - Utilizando masks y selecciones, cuente cuántos meteoritos H4 cayeron entre 1960 y 1990.
# - Utilizando masks y selecciones, cuente cuántos meteoritos H5 cayeron entre 1960 y 1990.
# - Concatene ambos dataframes y grafique la cantidad de meteoritos por clase y por año

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
import seaborn as sb


source= "../Sesión 3/meteorite-landings.csv"

meteo=pd.read_csv(source)
meteo.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
meteoritos_h4= meteo[(meteo.recclass.str.len()==2)&(meteo.recclass.str.contains('H4'))]
meteoritos_h5=meteo[(meteo.recclass.str.contains('H5'))&(meteo.recclass.str.len()==2)]

meteoritos_h4
# Out:
#                    name     id nametype recclass      mass   fall    year  \
# 14             Akbarpur    427    Valid       H4   1800.00   Fell  1838.0
# 26        Alexandrovsky    465    Valid       H4   9251.00   Fell  1900.0
# 40              Ankober   2304    Valid       H4   6500.00   Fell  1942.0
# 60          Avanhandava   4905    Valid       H4   9330.00   Fell  1952.0
# 84                 Bath   4974    Valid       H4  21000.00   Fell  1892.0
# ...                 ...    ...      ...      ...       ...    ...     ...
# 45611     Yamato 984055  40675    Valid       H4     21.56  Found  1998.0
# 45615     Yamato 984063  40683    Valid       H4     12.89  Found  1998.0
# 45672           Ybbsitz  30360    Valid       H4  15000.00  Found  1977.0
# 45674  Yelland Dry Lake  52641    Valid       H4  76000.00  Found  2007.0
# 45713              Zlin  30410    Valid       H4      3.30  Found  1939.0
#
#          reclat    reclong               GeoLocation
# ...

# %%
meteoritos_h5
# Out:
#                    name     id nametype recclass     mass   fall    year  \
# 7                  Agen    392    Valid       H5  30000.0   Fell  1814.0
# 25          Alessandria    463    Valid       H5    908.0   Fell  1860.0
# 28              Allegan   2276    Valid       H5  32000.0   Fell  1899.0
# 32        Ambapur Nagla   2290    Valid       H5   6400.0   Fell  1895.0
# 41               Anlong   2305    Valid       H5   2500.0   Fell  1971.0
# ...                 ...    ...      ...      ...      ...    ...     ...
# 45665   Yarle Lakes 001  30353    Valid       H5    913.0  Found  1990.0
# 45682  Yorktown (Texas)  30371    Valid       H5   3500.0  Found  1957.0
# 45688         Yucca 016  57158    Valid       H5     25.9  Found  2011.0
# 45689         Yucca 017  57159    Valid       H5    200.0  Found  2011.0
# 45706           Zerkaly  31354    Valid       H5  16000.0  Found  1956.0
#
#          reclat    reclong               GeoLocation
# ...

# %%
meteoritos_h4= meteoritos_h4[(meteoritos_h4['mass']!=0)& (pd.notnull(meteoritos_h4['mass'])) &(pd.notna(meteoritos_h4['mass']))]
meteoritos_h5= meteoritos_h5[(meteoritos_h5['mass']!=0)& (pd.notnull(meteoritos_h5['mass'])) &(pd.notna(meteoritos_h5['mass']))]

meteoritos_h4
# Out:
#                    name     id nametype recclass      mass   fall    year  \
# 14             Akbarpur    427    Valid       H4   1800.00   Fell  1838.0
# 26        Alexandrovsky    465    Valid       H4   9251.00   Fell  1900.0
# 40              Ankober   2304    Valid       H4   6500.00   Fell  1942.0
# 60          Avanhandava   4905    Valid       H4   9330.00   Fell  1952.0
# 84                 Bath   4974    Valid       H4  21000.00   Fell  1892.0
# ...                 ...    ...      ...      ...       ...    ...     ...
# 45611     Yamato 984055  40675    Valid       H4     21.56  Found  1998.0
# 45615     Yamato 984063  40683    Valid       H4     12.89  Found  1998.0
# 45672           Ybbsitz  30360    Valid       H4  15000.00  Found  1977.0
# 45674  Yelland Dry Lake  52641    Valid       H4  76000.00  Found  2007.0
# 45713              Zlin  30410    Valid       H4      3.30  Found  1939.0
#
#          reclat    reclong               GeoLocation
# ...

# %%
meteoritos_h5
# Out:
#                    name     id nametype recclass     mass   fall    year  \
# 7                  Agen    392    Valid       H5  30000.0   Fell  1814.0
# 25          Alessandria    463    Valid       H5    908.0   Fell  1860.0
# 28              Allegan   2276    Valid       H5  32000.0   Fell  1899.0
# 32        Ambapur Nagla   2290    Valid       H5   6400.0   Fell  1895.0
# 41               Anlong   2305    Valid       H5   2500.0   Fell  1971.0
# ...                 ...    ...      ...      ...      ...    ...     ...
# 45665   Yarle Lakes 001  30353    Valid       H5    913.0  Found  1990.0
# 45682  Yorktown (Texas)  30371    Valid       H5   3500.0  Found  1957.0
# 45688         Yucca 016  57158    Valid       H5     25.9  Found  2011.0
# 45689         Yucca 017  57159    Valid       H5    200.0  Found  2011.0
# 45706           Zerkaly  31354    Valid       H5  16000.0  Found  1956.0
#
#          reclat    reclong               GeoLocation
# ...

# %%
year_h4 = meteoritos_h4[(meteoritos_h4['year'] >= 1960) & (meteoritos_h4['year'] <= 1990)]
year_h4
# Out:
#                name     id nametype recclass      mass   fall    year  \
# 193           Chela   5338    Valid       H4   2936.00   Fell  1988.0
# 196     Chernyi Bor   5339    Valid       H4   6000.00   Fell  1964.0
# 213       Conquista   5418    Valid       H4  20350.00   Fell  1965.0
# 432            Kabo  12220    Valid       H4  13400.00   Fell  1971.0
# 589         Marilia  15422    Valid       H4   2500.00   Fell  1971.0
# ...             ...    ...      ...      ...       ...    ...     ...
# 43422  Yamato 86715  30221    Valid       H4     31.75  Found  1986.0
# 43453  Yamato 86746  30252    Valid       H4      6.37  Found  1986.0
# 43454  Yamato 86747  30253    Valid       H4      3.63  Found  1986.0
# 43456  Yamato 86749  30255    Valid       H4     21.24  Found  1986.0
# 45672       Ybbsitz  30360    Valid       H4  15000.00  Found  1977.0
#
#          reclat   reclong               GeoLocation
# 193    -3.66667  32.50000    (-3.666670, 32.500000)
# ...

# %%
year_h5 = meteoritos_h5[(meteoritos_h5['year'] >= 1960) & (meteoritos_h5['year'] <= 1990)]
year_h5
# Out:
#                     name     id nametype recclass      mass   fall    year  \
# 41                Anlong   2305    Valid       H5   2500.00   Fell  1971.0
# 116            Binningup   5051    Valid       H5    488.10   Fell  1984.0
# 185              Changde   5322    Valid       H5   1810.00   Fell  1977.0
# 270                Ehole   7774    Valid       H5   2400.00   Fell  1961.0
# 275    El Paso de Aguila  45977    Valid       H5  17226.00   Fell  1977.0
# ...                  ...    ...      ...      ...       ...    ...     ...
# 43421       Yamato 86714  30220    Valid       H5     11.38  Found  1986.0
# 43445       Yamato 86738  30244    Valid       H5      1.75  Found  1986.0
# 43455       Yamato 86748  30254    Valid       H5    595.24  Found  1986.0
# 43457       Yamato 86750  30256    Valid       H5      3.99  Found  1986.0
# 45665    Yarle Lakes 001  30353    Valid       H5    913.00  Found  1990.0
#
#          reclat    reclong               GeoLocation
# ...

# %%
meteoritos_t=pd.concat([year_h4,year_h5])
meteoritos_t
# Out:
#                   name     id nametype recclass      mass   fall    year  \
# 193              Chela   5338    Valid       H4   2936.00   Fell  1988.0
# 196        Chernyi Bor   5339    Valid       H4   6000.00   Fell  1964.0
# 213          Conquista   5418    Valid       H4  20350.00   Fell  1965.0
# 432               Kabo  12220    Valid       H4  13400.00   Fell  1971.0
# 589            Marilia  15422    Valid       H4   2500.00   Fell  1971.0
# ...                ...    ...      ...      ...       ...    ...     ...
# 43421     Yamato 86714  30220    Valid       H5     11.38  Found  1986.0
# 43445     Yamato 86738  30244    Valid       H5      1.75  Found  1986.0
# 43455     Yamato 86748  30254    Valid       H5    595.24  Found  1986.0
# 43457     Yamato 86750  30256    Valid       H5      3.99  Found  1986.0
# 45665  Yarle Lakes 001  30353    Valid       H5    913.00  Found  1990.0
#
#          reclat    reclong               GeoLocation
# ...

# %%
p1=year_h4.groupby('year')['recclass'].count()
p2=year_h5.groupby('year')['recclass'].count()

# %%
p1.plot(color='green')
p2.plot(color='magenta')
pt.title('Meteoritos por año')
# Out:
# Text(0.5, 1.0, 'Meteoritos por año')
